# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../scripts")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (14,6)

# %%
obs = pd.read_csv("../data/obs_arg.csv", parse_dates=["date"])
obs = obs.set_index("date")
obs = obs.drop(columns=["Total_Confirmed"])
obs
# Out:
#                 I     R    D
# date
# 2020-03-03      1     0    0
# 2020-03-04      1     0    0
# 2020-03-05      1     0    0
# 2020-03-06      2     0    0
# 2020-03-07      8     0    0
# ...           ...   ...  ...
# 2020-06-05  14317  6088  632
# 2020-06-06  15192  6180  648
# 2020-06-07  15221  6909  664
# 2020-06-08  15622  7305  693
# 2020-06-09  16476  7568  717
#
# [99 rows x 3 columns]

# %%
obs = obs.reset_index(drop=True)

# %%
obs.plot()

# %%
obs = obs.rolling(window=7, min_periods=1).mean()

# %%
obs.plot()

# %%
len(obs)
# Out:
# 99

# %%
train = obs.iloc[:90]
test = obs.iloc[90:]

# %%
train.plot()

# %%
test.plot()

# %% [markdown]
# ## SIR

# %%
from SEIR import SIR

# %%
init_I, init_R, init_D = train.head(1).to_numpy().flatten()

# %%
model = SIR(population=1e4, init_infected=init_I, init_recovered=init_R, init_dead=init_D)

# %%
model.fit(train, estimate=('r_transmission', "r_recovery", "r_mortality", "population"), 
          method="Nelder-Mead", options={"maxiter": 5000})
# Out:
#  final_simplex: (array([[7.08988899e-02, 2.27311950e-02, 3.09934737e-03, 8.73678787e+14],
#        [7.08988899e-02, 2.27311950e-02, 3.09934737e-03, 8.73678787e+14],
#        [7.08988899e-02, 2.27311950e-02, 3.09934737e-03, 8.73678787e+14],
#        [7.08988899e-02, 2.27311950e-02, 3.09934737e-03, 8.73678787e+14],
#        [7.08988899e-02, 2.27311950e-02, 3.09934737e-03, 8.73678787e+14]]), array([6549769.50823785, 6549769.50823876, 6549769.50823876,
#        6549769.50823876, 6549769.50823876]))
#            fun: 6549769.508237852
#        message: 'Optimization terminated successfully.'
#           nfev: 1409
#            nit: 762
#         status: 0
#        success: True
#              x: array([7.08988899e-02, 2.27311950e-02, 3.09934737e-03, 8.73678787e+14])

# %%
model.params
# Out:
# {'population': 873678787267322.5,
#  'r_transmission': 0.07089888989566207,
#  'r_recovery': 0.022731195009827315,
#  'r_mortality': 0.003099347365913859}

# %%
T = len(train) + len(test)
res = model.simulate(until=T)
idx = pd.date_range(start=data_start, periods=T, freq="D")
res.index = idx

# %%
ax = res.plot()
train.plot(ax=ax, style="--")
test.plot(ax=ax, style=".")

# %% [markdown]
# ## SEIR

# %%
from SEIR import SEIR

# %%
model = SEIR(population=44e6, init_infected=init_I, init_recovered=init_R, init_dead=init_D, init_exposed=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-b337dfbe141c> in <module>
# ----> 1 model = SEIR(population=44e6, init_infected=init_I, init_recovered=init_R, init_dead=init_D, init_exposed=500)
#
# NameError: name 'SEIR' is not defined

# %%
model.fit(train, estimate=('r_transmission', "r_progression", "r_recovery", "r_mortality", "population"),
          method="Nelder-Mead", options={"maxiter": 5000})
# Out:
#  final_simplex: (array([[0.08424779, 0.02144885, 0.14726334, 0.00293826],
#        [0.08424783, 0.02144884, 0.14726301, 0.00293825],
#        [0.08424772, 0.02144884, 0.14726352, 0.00293825],
#        [0.08424773, 0.02144884, 0.14726341, 0.00293824],
#        [0.08424773, 0.02144883, 0.14726345, 0.00293826]]), array([5165532.68703354, 5165532.68703807, 5165532.68705483,
#        5165532.68711347, 5165532.68713057]))
#            fun: 5165532.687033537
#        message: 'Optimization terminated successfully.'
#           nfev: 793
#            nit: 478
#         status: 0
#        success: True
#              x: array([0.08424779, 0.02144885, 0.14726334, 0.00293826])

# %%
T = len(train) + len(test)
res = model.simulate(until=T)
idx = pd.date_range(start=data_start, periods=T, freq="D")
res.index = idx

# %%
ax = res.plot()
train.plot(ax=ax, style="--")
test.plot(ax=ax, style=".")

# %% [markdown]
# ## SEIRH

# %%
from SEIR import SEIRH

# %%
model = SEIRH(init_infected=init_I, init_recovered=init_R, init_dead=init_D, 
              init_exposed=1000, init_hospitalized=100,
              r_hospitalized=0.05, r_recovery_hosp=0.01, r_recovery_mild=0.1)

# %%
model.fit(train, estimate=('r_transmission', "r_progression", "r_mortality", 
                           "r_hospitalized", "r_recovery_hosp", "r_recovery_mild"), 
          method="Nelder-Mead", options={"maxiter": 10000})
# Out:
#  final_simplex: (array([[ 1.53047407e-01,  2.15572068e-02,  3.86711613e-03,
#          9.72831244e-02, -1.00706254e-04,  4.42562556e-02],
#        [ 1.53047631e-01,  2.15573649e-02,  3.86710530e-03,
#          9.72830841e-02, -1.00907048e-04,  4.42562195e-02],
#        [ 1.53047898e-01,  2.15572708e-02,  3.86709847e-03,
#          9.72830247e-02, -1.00781289e-04,  4.42564477e-02],
#        [ 1.53047474e-01,  2.15571944e-02,  3.86710854e-03,
#          9.72831066e-02, -1.00693108e-04,  4.42563007e-02],
#        [ 1.53047864e-01,  2.15572870e-02,  3.86710239e-03,
#          9.72830364e-02, -1.00802899e-04,  4.42564130e-02],
#        [ 1.53047615e-01,  2.15572020e-02,  3.86711242e-03,
#          9.72830677e-02, -1.00676065e-04,  4.42563739e-02],
#        [ 1.53047628e-01,  2.15572179e-02,  3.86711792e-03,
#          9.72830875e-02, -1.00717849e-04,  4.42563735e-02]]), array([5318536.16716272, 5318536.16718198, 5318536.16718319,
#        5318536.16718488, 5318536.16719658, 5318536.16720488,
#        5318536.1672572 ]))
#            fun: 5318536.167162724
#        message: 'Optimization terminated successfully.'
#           nfev: 936
#            nit: 593
#         status: 0
#        success: True
#              x: array([ 1.53047407e-01,  2.15572068e-02,  3.86711613e-03,  9.72831244e-02,
#        -1.00706254e-04,  4.42562556e-02])

# %%
T = len(train) + len(test)
res = model.simulate(until=T)
idx = pd.date_range(start=data_start, periods=T, freq="D")
res.index = idx

# %%
ax = res.plot()
train.plot(ax=ax, style="--")
test.plot(ax=ax, style=".")

# %% [markdown]
# # Piecewise SIR

# %%
from SEIR import SIR

# %%
model = SIR(population = 1e6, init_infected=1, init_recovered=0, init_dead=0)

# %%
model.fit_piecewise(train, estimate=('r_transmission', "r_recovery", "r_mortality"), batch_size=10)
# Out:
# ----------------------
# Batch 0
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 1
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 2
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 3
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 4
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 5
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 6
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 7
#
# Fitting...
# Simulating...
# Done!
# ----------------------
# Batch 8
#
# Fitting...
# Simulating...
# Done!

# %%
ax = model.output_insample.plot()
train.plot(ax=ax, style=".")

# %%
pred = model.simulate(len(test))

# %%
pred.index = test.index

# %%
ax = pred.plot()
test.plot(ax=ax, style=".")

# %%
out = pd.concat((insample, pred))

# %%
out = out.reset_index(drop=True)

# %%
ax = out.plot()
obs.plot(ax=ax)

# %%
ax = pred.plot()
test.reset_index(drop=True).plot(ax=ax, style=".")
