# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../scripts")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (14,6)

# %%
obs = pd.read_csv("../data/obs_arg.csv", parse_dates=["date"])
obs = obs.set_index("date")
obs
# Out:
#                I     R    D  Total_Confirmed
# date
# 2020-03-03     1     0    0                1
# 2020-03-04     1     0    0                1
# 2020-03-05     1     0    0                1
# 2020-03-06     2     0    0                2
# 2020-03-07     8     0    0                8
# ...          ...   ...  ...              ...
# 2020-05-08  3659  1659  293             5611
# 2020-05-09  3748  1728  300             5776
# 2020-05-10  3972  1757  305             6034
# 2020-05-11  4127  1837  314             6278
# 2020-05-12  4382  1862  319             6563
#
# [71 rows x 4 columns]

# %%
obs.plot()

# %%
obs = obs.rolling(window=7, min_periods=1).mean()

# %%
obs.plot()

# %%
recovery_rate = (obs.R / obs.Total_Confirmed).tail(5).mean() / 10
recovery_rate
# Out:
# 0.029368486307299813

# %%
mortality_rate = (obs.D / obs.Total_Confirmed).tail(5).mean() / 10
mortality_rate
# Out:
# 0.005188005991794689

# %%
target = obs["2020-04-01":"2020-04-30"].copy()
target = target.drop(columns=["Total_Confirmed"])
target.tail()
# Out:
#                       I            R           D
# date
# 2020-04-26  2313.714286   925.857143  164.714286
# 2020-04-27  2399.142857   983.428571  173.428571
# 2020-04-28  2501.142857  1029.428571  182.000000
# 2020-04-29  2609.571429  1075.142857  190.857143
# 2020-04-30  2695.714286  1123.285714  198.428571

# %%
test = obs["2020-05-01":"2020-05-15"].copy()
test = test.drop(columns=["Total_Confirmed"])
test.head()
# Out:
#                       I            R           D
# date
# 2020-05-01  2775.714286  1168.428571  205.428571
# 2020-05-02  2855.571429  1209.857143  212.857143
# 2020-05-03  2939.857143  1245.142857  220.571429
# 2020-05-04  3014.000000  1288.285714  229.571429
# 2020-05-05  3089.142857  1332.571429  237.714286

# %%
from SEIR import SIRD

# %%
model = SIRD(population=44e6, recovery_rate=recovery_rate, mortality_rate=mortality_rate, beta=0.05)

# %%
x = np.linspace(0, 1, num=30)
y = x**3
y = 1 / y.sum() * y
weights = y.reshape((-1,1)) * 1/3 * np.ones((1,3))

# %%
weights = np.zeros((30,3))
weights[25:,:] = 1
M = weights[weights.nonzero()].size
weights = 1 / M * weights

# %%
weights = np.zeros((30,3))
weights[::7,:] = 1
M = weights[weights.nonzero()].size
weights = 1 / M * weights

# %%
weights.sum()
# Out:
# 1.0

# %%
model.fit(target, estimate=('beta', "mortality_rate", "recovery_rate"), weights=None, method="Nelder-Mead")
# Out:
#  final_simplex: (array([[0.08253537, 0.00455169, 0.02409102],
#        [0.08253484, 0.0045513 , 0.02409069],
#        [0.08253648, 0.00455268, 0.02409071],
#        [0.08253699, 0.00455211, 0.02409163]]), array([10264.17005576, 10264.17009003, 10264.1701085 , 10264.17011379]))
#            fun: 10264.17005576386
#        message: 'Optimization terminated successfully.'
#           nfev: 202
#            nit: 115
#         status: 0
#        success: True
#              x: array([0.08253537, 0.00455169, 0.02409102])

# %%
y0 = target.head(1).to_numpy().flatten()
res = model.simulate(y0, until=42)

# %%
ax = res.plot()
pd.concat((target, test)).reset_index(drop=True).plot(ax=ax)
