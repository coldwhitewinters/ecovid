# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (14,6)

# %%
confirmed = pd.read_csv("../data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
deaths = pd.read_csv("../data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
recovered = pd.read_csv("../data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

# %%
confirmed.rename(columns={"Country/Region":"Country", "Province/State":"Province"}, inplace=True)
recovered.rename(columns={"Country/Region":"Country", "Province/State":"Province"}, inplace=True)
deaths.rename(columns={"Country/Region":"Country", "Province/State":"Province"}, inplace=True)

# %%
confirmed = confirmed[confirmed.Province.notna()].drop(columns=["Lat", "Long"]).set_index(["Country", "Province"]).T
recovered = recovered[recovered.Province.notna()].drop(columns=["Lat", "Long"]).set_index(["Country", "Province"]).T
deaths = deaths[deaths.Province.notna()].drop(columns=["Lat", "Long"]).set_index(["Country", "Province"]).T

# %%
confirmed
# Out:
# Country                     Australia                                     \
# Province Australian Capital Territory New South Wales Northern Territory
# 1/22/20                             0               0                  0
# 1/23/20                             0               0                  0
# 1/24/20                             0               0                  0
# 1/25/20                             0               0                  0
# 1/26/20                             0               3                  0
# ...                               ...             ...                ...
# 6/5/20                            107            3110                 29
# 6/6/20                            108            3109                 29
# 6/7/20                            108            3112                 29
# 6/8/20                            108            3114                 29
# 6/9/20                            108            3117                 29
#
# Country                                                                  \
# Province Queensland South Australia Tasmania Victoria Western Australia
# 1/22/20           0               0        0        0                 0
# 1/23/20           0               0        0        0                 0
# 1/24/20           0               0        0        0                 0
# 1/25/20           0               0        0        0                 0
# 1/26/20           0               0        0        1                 0
# ...             ...             ...      ...      ...               ...
# 6/5/20         1061             440      228     1681               596
# 6/6/20         1061             440      228     1685               599
# 6/7/20         1062             440      228     1687               599
# 6/8/20         1062             440      228     1687               599
# 6/9/20         1062             440      228     1691               599
#
# Country   Canada                   ... United Kingdom           Canada  \
# Province Alberta British Columbia  ...     Montserrat Diamond Princess
# 1/22/20        0                0  ...              0                0
# 1/23/20        0                0  ...              0                0
# 1/24/20        0                0  ...              0                0
# 1/25/20        0                0  ...              0                0
# 1/26/20        0                0  ...              0                0
# ...          ...              ...  ...            ...              ...
# 6/5/20      7098             2632  ...             11                0
# 6/6/20      7138             2632  ...             11                0
# 6/7/20      7138             2632  ...             11                0
# 6/8/20      7202             2659  ...             11                0
# 6/9/20      7229             2669  ...             11                0
#
# Country                              United Kingdom                         \
# Province Northwest Territories Yukon       Anguilla British Virgin Islands
# 1/22/20                      0     0              0                      0
# 1/23/20                      0     0              0                      0
# 1/24/20                      0     0              0                      0
# 1/25/20                      0     0              0                      0
# 1/26/20                      0     0              0                      0
# ...                        ...   ...            ...                    ...
# 6/5/20                       5    11              3                      8
# 6/6/20                       5    11              3                      8
# 6/7/20                       5    11              3                      8
# 6/8/20                       5    11              3                      8
# 6/9/20                       5    11              3                      8
#
# Country                                                Netherlands  \
# Province Turks and Caicos Islands Bonaire, Sint Eustatius and Saba
# 1/22/20                         0                                0
# 1/23/20                         0                                0
# 1/24/20                         0                                0
# 1/25/20                         0                                0
# 1/26/20                         0                                0
# ...                           ...                              ...
# 6/5/20                         12                                7
# 6/6/20                         12                                7
# 6/7/20                         12                                7
# 6/8/20                         12                                7
# 6/9/20                         12                                7
#
# Country               United Kingdom                    France
# Province Falkland Islands (Malvinas) Saint Pierre and Miquelon
# 1/22/20                            0                         0
# 1/23/20                            0                         0
# 1/24/20                            0                         0
# 1/25/20                            0                         0
# 1/26/20                            0                         0
# ...                              ...                       ...
# 6/5/20                            13                         1
# 6/6/20                            13                         1
# 6/7/20                            13                         1
# 6/8/20                            13                         1
# 6/9/20                            13                         1
#
# [140 rows x 81 columns]

# %%
infected = confirmed - recovered - deaths

# %%
data = pd.concat([infected, recovered, deaths, confirmed], axis=1, keys=["I", "R", "D", "C"]).swaplevel(0, 2, axis=1).swaplevel(0,1,axis=1).sort_index(axis=1)

# %%
data.index.name = "date"

# %%
data.isna().sum().sum()
# Out:
# 1960

# %%
ds = data.isna().sum()
ds[ds != 0]
# Out:
# Country  Province
# Canada   Alberta                    I    140
#          British Columbia           I    140
#          Diamond Princess           I    140
#          Grand Princess             I    140
#          Manitoba                   I    140
#          New Brunswick              I    140
#          Newfoundland and Labrador  I    140
#          Northwest Territories      I    140
#          Nova Scotia                I    140
#          Ontario                    I    140
#          Prince Edward Island       I    140
#          Quebec                     I    140
#          Saskatchewan               I    140
#          Yukon                      I    140
# dtype: int64

# %%
data.loc[:, "Canada"]
# Out:
# Province Alberta          British Columbia          Diamond Princess         \
#                C    D   I                C    D   I                C  D   I
# date
# 1/22/20        0    0 NaN                0    0 NaN                0  0 NaN
# 1/23/20        0    0 NaN                0    0 NaN                0  0 NaN
# 1/24/20        0    0 NaN                0    0 NaN                0  0 NaN
# 1/25/20        0    0 NaN                0    0 NaN                0  0 NaN
# 1/26/20        0    0 NaN                0    0 NaN                0  0 NaN
# ...          ...  ...  ..              ...  ...  ..              ... ..  ..
# 6/5/20      7098  146 NaN             2632  167 NaN                0  1 NaN
# 6/6/20      7138  146 NaN             2632  167 NaN                0  1 NaN
# 6/7/20      7138  146 NaN             2632  167 NaN                0  1 NaN
# 6/8/20      7202  149 NaN             2659  167 NaN                0  1 NaN
# 6/9/20      7229  151 NaN             2669  167 NaN                0  1 NaN
#
# Province Grand Princess  ... Prince Edward Island Quebec            \
#                       C  ...                    I      C     D   I
# date                     ...
# 1/22/20               0  ...                  NaN      0     0 NaN
# 1/23/20               0  ...                  NaN      0     0 NaN
# 1/24/20               0  ...                  NaN      0     0 NaN
# 1/25/20               0  ...                  NaN      0     0 NaN
# 1/26/20               0  ...                  NaN      0     0 NaN
# ...                 ...  ...                  ...    ...   ...  ..
# 6/5/20               13  ...                  NaN  52398  4935 NaN
# 6/6/20               13  ...                  NaN  52624  4970 NaN
# 6/7/20               13  ...                  NaN  52849  4978 NaN
# 6/8/20               13  ...                  NaN  53047  4984 NaN
# 6/9/20               13  ...                  NaN  53185  5029 NaN
#
# Province Saskatchewan         Yukon
#                     C   D   I     C  D   I
# date
# 1/22/20             0   0 NaN     0  0 NaN
# 1/23/20             0   0 NaN     0  0 NaN
# 1/24/20             0   0 NaN     0  0 NaN
# 1/25/20             0   0 NaN     0  0 NaN
# 1/26/20             0   0 NaN     0  0 NaN
# ...               ...  ..  ..   ... ..  ..
# 6/5/20            649  11 NaN    11  0 NaN
# 6/6/20            650  11 NaN    11  0 NaN
# 6/7/20            650  11 NaN    11  0 NaN
# 6/8/20            654  13 NaN    11  0 NaN
# 6/9/20            656  13 NaN    11  0 NaN
#
# [140 rows x 42 columns]

# %%
data = data.drop(columns=["Canada"], level=0)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data = data.rolling(window=7).mean().dropna().astype("int64")
data
# Out:
# Country                     Australia                                        \
# Province Australian Capital Territory                       New South Wales
#                                     C    D         I      R               C
# date
# 1/22/20                           NaN  NaN       NaN    NaN             NaN
# 1/23/20                           NaN  NaN       NaN    NaN             NaN
# 1/24/20                           NaN  NaN       NaN    NaN             NaN
# 1/25/20                           NaN  NaN       NaN    NaN             NaN
# 1/26/20                           NaN  NaN       NaN    NaN             NaN
# ...                               ...  ...       ...    ...             ...
# 6/5/20                     107.000000  3.0  0.000000  104.0     3103.857143
# 6/6/20                     107.142857  3.0  0.142857  104.0     3105.857143
# 6/7/20                     107.285714  3.0  0.285714  104.0     3107.857143
# 6/8/20                     107.428571  3.0  0.428571  104.0     3109.285714
# 6/9/20                     107.571429  3.0  0.571429  104.0     3111.142857
#
# Country                                                          ...  \
# Province                                Northern Territory       ...
#              D           I            R                  C    D  ...
# date                                                             ...
# 1/22/20    NaN         NaN          NaN                NaN  NaN  ...
# 1/23/20    NaN         NaN          NaN                NaN  NaN  ...
# 1/24/20    NaN         NaN          NaN                NaN  NaN  ...
# 1/25/20    NaN         NaN          NaN                NaN  NaN  ...
# 1/26/20    NaN         NaN          NaN                NaN  NaN  ...
# ...        ...         ...          ...                ...  ...  ...
# 6/5/20    48.0  358.571429  2697.285714               29.0  0.0  ...
# 6/6/20    48.0  355.142857  2702.714286               29.0  0.0  ...
# 6/7/20    48.0  351.571429  2708.285714               29.0  0.0  ...
# 6/8/20    48.0  347.000000  2714.285714               29.0  0.0  ...
# 6/9/20    48.0  342.571429  2720.571429               29.0  0.0  ...
#
# Country  United Kingdom                                         \
# Province    Isle of Man             Montserrat
#                       I           R          C    D    I     R
# date
# 1/22/20             NaN         NaN        NaN  NaN  NaN   NaN
# 1/23/20             NaN         NaN        NaN  NaN  NaN   NaN
# 1/24/20             NaN         NaN        NaN  NaN  NaN   NaN
# 1/25/20             NaN         NaN        NaN  NaN  NaN   NaN
# 1/26/20             NaN         NaN        NaN  NaN  NaN   NaN
# ...                 ...         ...        ...  ...  ...   ...
# 6/5/20         1.142857  310.857143       11.0  1.0  0.0  10.0
# 6/6/20         0.714286  311.285714       11.0  1.0  0.0  10.0
# 6/7/20         0.285714  311.714286       11.0  1.0  0.0  10.0
# 6/8/20         0.142857  311.857143       11.0  1.0  0.0  10.0
# 6/9/20         0.000000  312.000000       11.0  1.0  0.0  10.0
#
# Country
# Province Turks and Caicos Islands
#                                 C    D    I     R
# date
# 1/22/20                       NaN  NaN  NaN   NaN
# 1/23/20                       NaN  NaN  NaN   NaN
# 1/24/20                       NaN  NaN  NaN   NaN
# 1/25/20                       NaN  NaN  NaN   NaN
# 1/26/20                       NaN  NaN  NaN   NaN
# ...                           ...  ...  ...   ...
# 6/5/20                       12.0  1.0  0.0  11.0
# 6/6/20                       12.0  1.0  0.0  11.0
# 6/7/20                       12.0  1.0  0.0  11.0
# 6/8/20                       12.0  1.0  0.0  11.0
# 6/9/20                       12.0  1.0  0.0  11.0
#
# [140 rows x 268 columns]

# %%
data.loc[:, pd.IndexSlice["China", "Hubei", :]].plot()

# %%
data.to_csv("../data/ts-country-and-province.csv", index=False)
