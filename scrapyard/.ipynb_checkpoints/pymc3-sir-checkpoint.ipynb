# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint, solve_ivp
from scipy.optimize import minimize
import pymc3 as pm
from pymc3.ode import DifferentialEquation
from functools import partial
import scipy.stats as st

# %%
plt.rcParams["figure.figsize"] = (14,6)

# %%
data = pd.read_csv("../data/obs.csv", parse_dates=["date"])
data
# Out:
#           date   I     R  D     C
# 0   2020-01-22   4     0  0     4
# 1   2020-01-23   6     0  0     6
# 2   2020-01-24  12     0  0    12
# 3   2020-01-25  20     0  0    20
# 4   2020-01-26  29     0  0    29
# ..         ...  ..   ... ..   ...
# 135 2020-06-05   0  1015  4  1019
# 136 2020-06-06   0  1015  4  1019
# 137 2020-06-07   0  1015  4  1019
# 138 2020-06-08   0  1015  4  1019
# 139 2020-06-09   0  1015  4  1019
#
# [140 rows x 5 columns]

# %%
data = data.drop(columns="C")
data = data.set_index("date")

# %%
data.plot();

# %%
data["R"] = data["R"] + data["D"]
data = data.drop(columns=["D"])

# %%
train = data[:"2020-04-01"].copy()
test = data["2020-04-02":].copy()

# %%
train.plot();

# %%
test.plot();

# %%
def SIR(y, t, p):
    N = p[0]
    beta = p[1]
    gamma = p[2]
    I = y[0] 
    R = y[1]
    
    S = N - I - R
    dI = beta * S * I / N - gamma * I
    dR = gamma * I
    return dI, dR

# %%
sir_model = DifferentialEquation(
    func=SIR,
    times=np.arange(0, len(train), 1),
    n_states=2, 
    n_theta=3,
    t0=0,
)

# %%
def SIR(t, y, p):
    S = p[0] - y[0] - y[1]
    dI = p[1] * S * y[0] / p[0] - p[2] * y[0]
    dR = p[2] * y[0]
    return dI, dR

# %%
def SIR(y, t, p):
    N = 3e6
    ds = -p[0]*y[0]*y[1] / N
    di = p[0]*y[0]*y[1] / N - p[1]*y[1]
    return [ds, di]

# %%
sir_model = DifferentialEquation(
    func=SIR,
    times=np.arange(0, len(train), 1),
    n_states=2,
    n_theta=2,
    t0=0,
)

# %%
def build_model(deqn, y0, t):
    def model(p):
        output = solve_ivp(deqn, t_span=(0,t), y0=y0, args=(p,), t_eval=np.arange(0,t,1))
        simulation = pd.DataFrame(data=output.y.T, index=output.t, columns=["I", "R"])
        return simulation
    return model

# %%
def distance(simulation, obs):
    sqd = (obs["I"] - simulation["I"])**2 + (obs["R"] - simulation["R"])**2
    return np.sqrt(sqd.sum())

# %%
y0 = train.head(1).to_numpy().flatten()
y0
# Out:
# array([4, 0], dtype=int64)

# %%
model = build_model(SIR, y0, len(train))

# %%
params = {"pop": 1.1e3, "beta":0.45, "gamma":1/17}
simulation = model(params)

ax=simulation.plot()
train.reset_index(drop=True).plot(ax=ax, style=".")

# %%
x = np.linspace(1e3-500,1e3+500, num=1000)
y = st.norm.pdf(x, loc=1e3, scale=200)
plt.plot(x, y)

# %%
(1/30, 1/15, 1/10)
# Out:
# (0.03333333333333333, 0.06666666666666667, 0.1)

# %%
prior = pyabc.Distribution(
    beta=pyabc.RV("uniform", 0.2, 0.6),
    gamma=pyabc.RV("uniform", 0, 0.2),
    pop=pyabc.RV("uniform", 5e2, 1.5e3)
)

# %%
prior = pyabc.Distribution(
    beta=pyabc.RV("norm", 0.5, 0.1),
    gamma=pyabc.RV("uniform", 0.01, 0.2),
    pop=pyabc.RV("norm", 1e3, 200)
)

# %%
abc = pyabc.ABCSMC(
    models=model,
    parameter_priors=prior,
    distance_function=distance,
    #population_size=50,
    #transitions=pyabc.LocalTransition(k_fraction=.3),
    eps=pyabc.MedianEpsilon()
)

# %%
abc.new(db_path, train.to_dict("list"))
# Out:
# INFO:History:Start <ABCSMC(id=16, start_time=2020-07-04 00:47:04.610973, end_time=None)>

# %%
h = abc.run(min_acceptance_rate=0.01)
# Out:
# INFO:ABC:Calibration sample before t=0.
# INFO:Epsilon:initial epsilon is 2346.4479542266
# INFO:ABC:t: 0, eps: 2346.4479542266.
# INFO:ABC:Acceptance rate: 100 / 190 = 5.2632e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 1805.5984630509317.
# INFO:ABC:Acceptance rate: 100 / 239 = 4.1841e-01, ESS=8.9445e+01.
# INFO:ABC:t: 2, eps: 1511.3056684895378.
# INFO:ABC:Acceptance rate: 100 / 220 = 4.5455e-01, ESS=8.6377e+01.
# INFO:ABC:t: 3, eps: 1283.225680190919.
# INFO:ABC:Acceptance rate: 100 / 274 = 3.6496e-01, ESS=9.4421e+01.
# INFO:ABC:t: 4, eps: 1081.879587248838.
# INFO:ABC:Acceptance rate: 100 / 258 = 3.8760e-01, ESS=9.4147e+01.
# INFO:ABC:t: 5, eps: 947.3386862005436.
# INFO:ABC:Acceptance rate: 100 / 244 = 4.0984e-01, ESS=8.7264e+01.
# INFO:ABC:t: 6, eps: 893.8325035325745.
# INFO:ABC:Acceptance rate: 100 / 193 = 5.1813e-01, ESS=8.9017e+01.
# INFO:ABC:t: 7, eps: 836.8620957777796.
# INFO:ABC:Acceptance rate: 100 / 182 = 5.4945e-01, ESS=9.4916e+01.
# INFO:ABC:t: 8, eps: 796.1755964806468.
# INFO:ABC:Acceptance rate: 100 / 239 = 4.1841e-01, ESS=9.4650e+01.
# INFO:ABC:t: 9, eps: 770.6578211758978.
# INFO:ABC:Acceptance rate: 100 / 217 = 4.6083e-01, ESS=8.9334e+01.
# INFO:ABC:t: 10, eps: 755.4317584914331.
# INFO:ABC:Acceptance rate: 100 / 218 = 4.5872e-01, ESS=9.5214e+01.
# INFO:ABC:t: 11, eps: 744.154344224518.
# INFO:ABC:Acceptance rate: 100 / 229 = 4.3668e-01, ESS=9.4619e+01.
# INFO:ABC:t: 12, eps: 736.9766116569974.
# INFO:ABC:Acceptance rate: 100 / 237 = 4.2194e-01, ESS=9.4644e+01.
# INFO:ABC:t: 13, eps: 732.5768239721667.
# INFO:ABC:Acceptance rate: 100 / 203 = 4.9261e-01, ESS=8.8313e+01.
# INFO:ABC:t: 14, eps: 730.199711435729.
# INFO:ABC:Acceptance rate: 100 / 219 = 4.5662e-01, ESS=9.3650e+01.
# INFO:ABC:t: 15, eps: 728.7308560829754.
# INFO:ABC:Acceptance rate: 100 / 218 = 4.5872e-01, ESS=8.9875e+01.
# INFO:ABC:t: 16, eps: 727.6315685110212.
# INFO:ABC:Acceptance rate: 100 / 206 = 4.8544e-01, ESS=7.9735e+01.
# INFO:ABC:t: 17, eps: 727.0622059761066.
# INFO:ABC:Acceptance rate: 100 / 204 = 4.9020e-01, ESS=8.8492e+01.
# INFO:ABC:t: 18, eps: 726.5244988042389.
# INFO:ABC:Acceptance rate: 100 / 226 = 4.4248e-01, ESS=9.5876e+01.
# INFO:ABC:t: 19, eps: 726.2051366202436.
# INFO:ABC:Acceptance rate: 100 / 210 = 4.7619e-01, ESS=8.1703e+01.
# INFO:ABC:t: 20, eps: 726.0288149578018.
# INFO:ABC:Acceptance rate: 100 / 276 = 3.6232e-01, ESS=9.4271e+01.
# INFO:ABC:t: 21, eps: 725.9039480080673.
# INFO:ABC:Acceptance rate: 100 / 189 = 5.2910e-01, ESS=9.3924e+01.
# INFO:ABC:t: 22, eps: 725.8450188977113.
# INFO:ABC:Acceptance rate: 100 / 210 = 4.7619e-01, ESS=8.0861e+01.
# INFO:ABC:t: 23, eps: 725.7936081860778.
# INFO:ABC:Acceptance rate: 100 / 264 = 3.7879e-01, ESS=9.2730e+01.
# INFO:ABC:t: 24, eps: 725.7646853830181.
# INFO:ABC:Acceptance rate: 100 / 264 = 3.7879e-01, ESS=8.9225e+01.
# INFO:ABC:t: 25, eps: 725.7541330646428.
# INFO:ABC:Acceptance rate: 100 / 182 = 5.4945e-01, ESS=9.3994e+01.
# INFO:ABC:t: 26, eps: 725.7441724468107.
# INFO:ABC:Acceptance rate: 100 / 242 = 4.1322e-01, ESS=9.2559e+01.
# INFO:ABC:t: 27, eps: 725.7385974339927.
# INFO:ABC:Acceptance rate: 100 / 231 = 4.3290e-01, ESS=8.6049e+01.
# INFO:ABC:t: 28, eps: 725.7357405963326.
# INFO:ABC:Acceptance rate: 100 / 239 = 4.1841e-01, ESS=9.3386e+01.
# INFO:ABC:t: 29, eps: 725.7341639961338.
# INFO:ABC:Acceptance rate: 100 / 220 = 4.5455e-01, ESS=9.0538e+01.
# INFO:ABC:t: 30, eps: 725.732620113224.
# INFO:ABC:Acceptance rate: 100 / 263 = 3.8023e-01, ESS=9.3039e+01.
# INFO:ABC:t: 31, eps: 725.7319309831273.
# INFO:ABC:Acceptance rate: 100 / 219 = 4.5662e-01, ESS=9.3186e+01.
# INFO:ABC:t: 32, eps: 725.7315134008164.
# INFO:ABC:Acceptance rate: 100 / 265 = 3.7736e-01, ESS=9.4760e+01.
# INFO:ABC:t: 33, eps: 725.7312969105186.
# INFO:ABC:Acceptance rate: 100 / 229 = 4.3668e-01, ESS=9.4212e+01.
# INFO:ABC:t: 34, eps: 725.7311178774266.
# INFO:ABC:Acceptance rate: 100 / 202 = 4.9505e-01, ESS=8.0666e+01.
# INFO:ABC:t: 35, eps: 725.7309690489975.
# INFO:ABC:Acceptance rate: 100 / 242 = 4.1322e-01, ESS=9.2598e+01.
# INFO:ABC:t: 36, eps: 725.7308997830899.
# INFO:ABC:Acceptance rate: 100 / 199 = 5.0251e-01, ESS=9.0457e+01.
# INFO:ABC:t: 37, eps: 725.7308534189084.
# INFO:ABC:Acceptance rate: 100 / 238 = 4.2017e-01, ESS=9.0352e+01.
# INFO:ABC:t: 38, eps: 725.7308240951074.
# INFO:ABC:Acceptance rate: 100 / 237 = 4.2194e-01, ESS=9.3353e+01.
# INFO:ABC:t: 39, eps: 725.7308122995847.
# INFO:ABC:Acceptance rate: 100 / 225 = 4.4444e-01, ESS=8.9704e+01.
# INFO:ABC:t: 40, eps: 725.730803025355.
# INFO:ABC:Acceptance rate: 100 / 217 = 4.6083e-01, ESS=8.6937e+01.
# INFO:ABC:t: 41, eps: 725.7307976361072.
# INFO:ABC:Acceptance rate: 100 / 266 = 3.7594e-01, ESS=9.0548e+01.
# INFO:ABC:t: 42, eps: 725.7307949139907.
# INFO:ABC:Acceptance rate: 100 / 239 = 4.1841e-01, ESS=9.2499e+01.
# INFO:ABC:t: 43, eps: 725.7307933033624.
# INFO:ABC:Acceptance rate: 100 / 221 = 4.5249e-01, ESS=8.9442e+01.
# INFO:ABC:t: 44, eps: 725.7307921083166.
# INFO:ABC:Acceptance rate: 100 / 240 = 4.1667e-01, ESS=9.0135e+01.
# INFO:ABC:t: 45, eps: 725.7307912271247.
# INFO:ABC:Acceptance rate: 100 / 233 = 4.2918e-01, ESS=8.2825e+01.
# INFO:ABC:t: 46, eps: 725.73079082048.
# INFO:ABC:Acceptance rate: 100 / 184 = 5.4348e-01, ESS=8.9269e+01.
# INFO:ABC:t: 47, eps: 725.7307904690972.
# INFO:ABC:Acceptance rate: 100 / 205 = 4.8780e-01, ESS=9.4137e+01.
# INFO:ABC:t: 48, eps: 725.7307902797429.
# INFO:ABC:Acceptance rate: 100 / 200 = 5.0000e-01, ESS=9.1057e+01.
# INFO:ABC:t: 49, eps: 725.7307901250746.
# INFO:ABC:Acceptance rate: 100 / 219 = 4.5662e-01, ESS=9.1616e+01.
# INFO:ABC:t: 50, eps: 725.7307900289078.
# INFO:ABC:Acceptance rate: 100 / 253 = 3.9526e-01, ESS=8.3784e+01.
# INFO:ABC:t: 51, eps: 725.7307899829176.
# INFO:ABC:Acceptance rate: 100 / 207 = 4.8309e-01, ESS=8.9592e+01.
# INFO:ABC:t: 52, eps: 725.7307899466932.
# INFO:ABC:Acceptance rate: 100 / 200 = 5.0000e-01, ESS=8.1339e+01.
# INFO:ABC:t: 53, eps: 725.7307899247159.
# INFO:ABC:Acceptance rate: 100 / 252 = 3.9683e-01, ESS=9.0436e+01.
# INFO:ABC:t: 54, eps: 725.7307899120043.
# INFO:ABC:Acceptance rate: 100 / 238 = 4.2017e-01, ESS=9.4316e+01.
# INFO:ABC:t: 55, eps: 725.7307899019978.
# INFO:ABC:Acceptance rate: 100 / 241 = 4.1494e-01, ESS=9.4908e+01.
# INFO:ABC:t: 56, eps: 725.7307898965358.
# INFO:ABC:Acceptance rate: 100 / 202 = 4.9505e-01, ESS=9.0184e+01.
# INFO:ABC:t: 57, eps: 725.7307898941947.
# INFO:ABC:Acceptance rate: 100 / 213 = 4.6948e-01, ESS=9.0767e+01.
# INFO:ABC:t: 58, eps: 725.7307898922587.
# INFO:ABC:Acceptance rate: 100 / 239 = 4.1841e-01, ESS=9.2608e+01.
# INFO:ABC:t: 59, eps: 725.730789891154.
# INFO:ABC:Acceptance rate: 100 / 218 = 4.5872e-01, ESS=9.1888e+01.
# INFO:ABC:t: 60, eps: 725.7307898906696.
# INFO:ABC:Acceptance rate: 100 / 212 = 4.7170e-01, ESS=9.5484e+01.
# INFO:ABC:t: 61, eps: 725.7307898902336.
# INFO:ABC:Acceptance rate: 100 / 225 = 4.4444e-01, ESS=8.6690e+01.
# INFO:ABC:t: 62, eps: 725.7307898899231.
# INFO:ABC:Acceptance rate: 100 / 264 = 3.7879e-01, ESS=9.1998e+01.
# INFO:ABC:t: 63, eps: 725.7307898897575.
# INFO:ABC:Acceptance rate: 100 / 241 = 4.1494e-01, ESS=9.1644e+01.
# INFO:ABC:t: 64, eps: 725.7307898896498.
# INFO:ABC:Acceptance rate: 100 / 246 = 4.0650e-01, ESS=9.3879e+01.
# INFO:ABC:t: 65, eps: 725.7307898895751.
# INFO:ABC:Acceptance rate: 100 / 251 = 3.9841e-01, ESS=9.1477e+01.
# INFO:ABC:t: 66, eps: 725.7307898895408.
# INFO:ABC:Acceptance rate: 100 / 223 = 4.4843e-01, ESS=9.1025e+01.
# INFO:ABC:t: 67, eps: 725.730789889521.
# INFO:ABC:Acceptance rate: 100 / 236 = 4.2373e-01, ESS=9.0422e+01.
# INFO:ABC:t: 68, eps: 725.7307898895049.
# INFO:ABC:Acceptance rate: 100 / 340 = 2.9412e-01, ESS=8.3284e+01.
# INFO:ABC:t: 69, eps: 725.7307898894925.
# INFO:ABC:Acceptance rate: 100 / 369 = 2.7100e-01, ESS=7.1309e+01.
# INFO:ABC:t: 70, eps: 725.7307898894837.
# INFO:ABC:Acceptance rate: 100 / 576 = 1.7361e-01, ESS=4.7366e+01.
# INFO:ABC:t: 71, eps: 725.7307898894794.
# INFO:ABC:Acceptance rate: 100 / 747 = 1.3387e-01, ESS=7.6998e+01.
# INFO:ABC:t: 72, eps: 725.730789889474.
# INFO:ABC:Acceptance rate: 100 / 817 = 1.2240e-01, ESS=8.0773e+01.
# INFO:ABC:t: 73, eps: 725.7307898894692.
# INFO:ABC:Acceptance rate: 100 / 1154 = 8.6655e-02, ESS=6.3393e+01.
# INFO:ABC:t: 74, eps: 725.7307898894646.
# INFO:ABC:Acceptance rate: 100 / 2147 = 4.6577e-02, ESS=7.8463e+01.
# INFO:ABC:t: 75, eps: 725.7307898894591.
# INFO:ABC:Acceptance rate: 100 / 3991 = 2.5056e-02, ESS=2.0336e+01.
# INFO:ABC:t: 76, eps: 725.7307898894526.
# INFO:ABC:Acceptance rate: 100 / 12896 = 7.7543e-03, ESS=6.0150e+01.
# INFO:ABC:Stopping: minimum acceptance rate.
# INFO:History:Done <ABCSMC(id=16, start_time=2020-07-04 00:47:04.610973, end_time=2020-07-04 00:51:50.635570)>

# %%
params = h.get_distribution()[0].mean().to_dict()
params
# Out:
# {'beta': 0.4244552268680885,
#  'gamma': 0.06290476057163279,
#  'pop': 1074.5001743774844}

# %%
params["beta"]/params["gamma"]
# Out:
# 6.7475851272772935

# %%
simulation = model(params)

ax=simulation.plot()
train.reset_index(drop=True).plot(ax=ax, style=".")

# %%
test_model = build_model(SIR, y0, len(train)+len(test))

# %%
simulation = test_model(params)
simulation.index = data.index

# %%
ax = simulation.plot()
data.plot(ax=ax, style=".")
